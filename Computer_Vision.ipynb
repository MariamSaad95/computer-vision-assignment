# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
# Reading the image
image = cv2.imread('beach.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=612x344>

# %%
# dividing height and width by 2 to get the center of the image
height, width = image.shape[:2]
# get the center coordinates of the image to create the 2D rotation matrix
center = (width/2, height/2)

# %% [markdown]
# #Rotation

# %%
rotate_matrix = cv2.getRotationMatrix2D(center=center, angle=45, scale=1)

# %%
rotated_image = cv2.warpAffine(src=image, M=rotate_matrix, dsize=(width, height))
cv2_imshow(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=612x344>

# %% [markdown]
# #translation

# %%
tx, ty = width / 4, height / 4

translation_matrix = np.array([
    [1, 0, tx],
    [0, 1, ty]
], dtype=np.float32)

# %%
translated_image = cv2.warpAffine(src=image, M=translation_matrix, dsize=(width, height))
cv2_imshow(translated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=612x344>

# %% [markdown]
# #scalling

# %%
scaled= cv2.resize(image,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)
cv2_imshow(scaled)
# Out:
# <PIL.Image.Image image mode=RGB size=1224x688>

# %% [markdown]
# #Perspective_transformation

# %%
pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
M = cv2.getPerspectiveTransform(pts1,pts2)
Perspective = cv2.warpPerspective(image,M,(300,300))
cv2_imshow(Perspective)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
